# %%
import pandas as pd
import datetime
import numpy as np
import os

# %%
filepath1 = os.path.join("Resources" ,"JC-201901-citibike-tripdata.csv")
filepath2 = os.path.join("Resources" ,"JC-201902-citibike-tripdata.csv")
filepath3 = os.path.join("Resources" ,"JC-201903-citibike-tripdata.csv")
filepath4 = os.path.join("Resources" ,"JC-201904-citibike-tripdata.csv")
filepath5 = os.path.join("Resources" ,"JC-201905-citibike-tripdata.csv")
filepath6 = os.path.join("Resources" ,"JC-201906-citibike-tripdata.csv")

nycbike_201901 = pd.read_csv(filepath1)
nycbike_201902 = pd.read_csv(filepath2)
nycbike_201903 = pd.read_csv(filepath3)
nycbike_201904 = pd.read_csv(filepath4)
nycbike_201905 = pd.read_csv(filepath5)
nycbike_201906 = pd.read_csv(filepath6)

# %%
nycbike_201906.head(3)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# 1               -74.043845            3267     Morris Canal
# 2               -74.032108            3199     Newport Pkwy
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.728745             -74.032108   29677  Subscriber
# ...

# %%
nycbike_all = pd.concat([nycbike_201901,nycbike_201902,nycbike_201903,nycbike_201904,nycbike_201905,nycbike_201906])

# %%
filepath = os.path.join("Resources" ,"nycbike_jan_jun2019.csv")
nycbike_all.to_csv(filepath,index=False)
nycbike_all.tail(3)
# Out:
#        tripduration                 starttime                  stoptime  \
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# 39427              3679         Bergen Ave               40.722104
# 39428              3185          City Hall               40.717733
# 39429              3210     Pershing Field               40.742677
#
#        start station longitude  end station id end station name  \
# 39427               -74.071455            3191         Union St
# 39428               -74.043845            3213   Van Vorst Park
# 39429               -74.051789            3186    Grove St PATH
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 39427             40.718211             -74.083639   29241  Subscriber
# ...
